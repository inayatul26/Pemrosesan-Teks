# %%
# !pip install google-play-scraper
# Out:
# Requirement already satisfied: google-play-scraper in /usr/local/lib/python3.12/dist-packages (1.2.7)

# %%
#import library
from google_play_scraper import Sort, reviews
from google_play_scraper import app
import pandas as pd
import numpy as np

# %%
#mulai scraping
result, continuation_token = reviews(
    'id.co.bankbkemobile.digitalbank',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=1000,
    filter_score_with=None
)

# %%
#membuat DataFrame dari hasil scraping
df = pd.DataFrame(np.array(result), columns=['review'])
df = df.join(pd.DataFrame(df.pop('review').tolist()))
df
# Out:
#                                  reviewId                     userName  \
# 0    dfd2805a-2290-4dbd-81be-8f7ceba88450  isikode[ HKUM86 ] dpt bonus
# 1    20543974-3a9b-4aba-b86b-66a86bd1f4f1                 Marcho Bagus
# 2    218e1cd4-0d53-49fa-a1c9-722123c0c741  isikode [ WUZASB ] dpt 30jt
# 3    d3a692c0-8256-4924-a805-0c4f8fd4b3bf                    Kepi Ogah
# 4    a0b4c48e-75c8-403b-9df1-b18f2d7c49cb                Anti Paylater
# ..                                    ...                          ...
# 995  5c9993d8-7d46-4978-9975-1c75d685fe56                 gemoy gaming
# 996  0b77a018-2435-4aa8-b97d-e83dda15e382                Rahmad ananda
# 997  fe0efdf8-0c23-4f4a-af32-292c0bd1a7c4                  Yuliaa 0794
# 998  b906a6ad-97fd-40e6-a046-88bdeb78b5e4                   Ida Rassya
# 999  a1b24390-79b9-495b-98da-d458d8372142       rambun pamenan (mbuik)
#
#                                              userImage  \
# 0    https://play-lh.googleusercontent.com/a-/ALV-U...
# 1    https://play-lh.googleusercontent.com/a/ACg8oc...
# 2    https://play-lh.googleusercontent.com/a-/ALV-U...
# 3    https://play-lh.googleusercontent.com/a/ACg8oc...
# 4    https://play-lh.googleusercontent.com/a-/ALV-U...
# ..                                                 ...
# 995  https://play-lh.googleusercontent.com/a/ACg8oc...
# 996  https://play-lh.googleusercontent.com/a-/ALV-U...
# 997  https://play-lh.googleusercontent.com/a-/ALV-U...
# 998  https://play-lh.googleusercontent.com/a-/ALV-U...
# 999  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                                content  score  thumbsUpCount  \
# 0    Asli oke bener, programnya dan internalnya leb...      5             74
# 1    maaf ... untuk saat ini aplikasinya lelet & su...      5              9
# 2    Asli bermanfaatt banget,programnya juga intern...      5             17
# 3    Asli praktis juga aman,terprogram dan interfac...      5             64
# 4    tidak bisa masuk ke akun seabank, ada notifica...      1              8
# ..                                                 ...    ...            ...
# 995  gampang di gunakan dan pengiriman ga lena biay...      5              0
# 996  nipu,katanya daftar dan masukin referal dapat ...      1              6
# 997  mau ganti kata sandi kode otp gak masuk" , log...      1              0
# 998  Alhamdulillah aplikasinya begitu mudah dan cep...      5              0
# 999  cukup bagus cuman kalo keluar akun masuk nya s...      4              0
#
#     reviewCreatedVersion                  at  \
# 0                 3.28.0 2025-10-01 14:40:42
# 1                 3.28.0 2025-10-04 09:06:27
# 2                 3.28.0 2025-09-29 00:02:58
# 3                 3.28.0 2025-09-24 09:33:40
# 4                 3.28.0 2025-10-05 08:30:50
# ..                   ...                 ...
# 995               3.23.4 2025-08-04 11:55:40
# 996               3.25.0 2025-08-28 06:11:02
# 997               3.25.0 2025-08-25 04:43:34
# 998               3.25.0 2025-09-01 02:57:03
# 999               3.23.4 2025-08-16 00:38:22
#
#                                           replyContent           repliedAt  \
# 0                                                 None                 NaT
# 1    Hai Sobat SeaBank, mohon maaf jika pelayanan k... 2025-10-04 13:27:18
# 2    Hai Sobat SeaBank, mohon maaf atas ketidaknyam... 2025-09-28 03:18:24
# 3                                                 None                 NaT
# 4    Hai Sobat SeaBank, mohon maaf atas ketidaknyam... 2025-10-05 09:24:37
# ..                                                 ...                 ...
# 995                                               None                 NaT
# 996  Hai Sobat SeaBank, sebelumnya kami mohon maaf.... 2025-08-28 07:06:18
# 997  Hi Sobat SeaBank, sebelumnya mohon maaf. Terka... 2025-08-25 05:52:44
# 998                                               None                 NaT
# 999  Hi Sobat SeaBank. Mohon maaf atas ketidaknyama... 2025-08-16 02:57:12
#
#     appVersion
# 0       3.28.0
# 1       3.28.0
# 2       3.28.0
# 3       3.28.0
# 4       3.28.0
# ..         ...
# 995     3.23.4
# 996     3.25.0
# 997     3.25.0
# 998     3.25.0
# 999     3.23.4
#
# [1000 rows x 11 columns]

# %%
df['content_casefold'] = df['content'].astype(str).str.lower()

# %%
df.to_csv("UlasanSeabank.csv", index=False, encoding='utf-8')
