# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.semi_supervised import SelfTrainingClassifier
from sklearn.linear_model import LogisticRegression
from scipy.sparse import vstack

# %%
df = pd.read_csv("/content/drive/MyDrive/pelabelanmanual.csv", sep=";")

# %%
df.head()
# Out:
#                                              content  score  \
# 0  suka berguna banget, program dan internalnya l...      5
# 1  Terbaru sangat praktis,program dan internalnya...      5
# 2  Asliii sangat praktis,program dan internalnya ...      5
# 3  Asli sangat praktis,program dan internalnya le...      5
# 4  Asli sangat praktis,program dan internalnya le...      5
#
#                                       review_cleaned   label
# 0  suka berguna banget program internalnya fleksi...  netral
# 1  terbaru praktis program internalnya memadai pa...  netral
# 2  asli praktis program internalnya memadai pakai...  netral
# 3  asli praktis program internalnya memadai pakai...  netral
# 4  asli praktis program internalnya memadai pakai...  netral

# %%
labeled_df = df[df["label"].notna()]
counts = labeled_df["label"].value_counts()
counts
# Out:
# label
# positif    100
# negatif    100
# netral      50
# Name: count, dtype: int64

# %%
text_col = "content"
label_col = "label"
labeled_df = df[df[label_col].notna()].copy()
unlabeled_df = df[df[label_col].isna()].copy()

X_labeled = labeled_df[text_col]
y_labeled = labeled_df[label_col]

X_unlabeled = unlabeled_df[text_col]

print("Jumlah data berlabel :", len(X_labeled))
print("Jumlah data belum berlabel :", len(X_unlabeled))
# Out:
# Jumlah data berlabel : 250
# Jumlah data belum berlabel : 750

# %%
#Encoding label menjadi angka
label_map = {label: i for i, label in enumerate(y_labeled.unique())}
inv_label_map = {v: k for k, v in label_map.items()}

y_labeled_enc = y_labeled.map(label_map)
y_unlabeled_enc = pd.Series([-1] * len(X_unlabeled))

# %%
#TF-IDF
vectorizer = TfidfVectorizer(max_features=3000)
X_labeled_vec = vectorizer.fit_transform(X_labeled)
X_unlabeled_vec = vectorizer.transform(X_unlabeled)

X_all = vstack([X_labeled_vec, X_unlabeled_vec])
y_all = pd.concat([y_labeled_enc, y_unlabeled_enc], ignore_index=True)

# %%
#self training
base_clf = LogisticRegression(max_iter=500)
self_training = SelfTrainingClassifier(
    base_clf,
    threshold=0.80,
    verbose=True
)

self_training.fit(X_all, y_all)
# Out:
# End of iteration 1, added 41 new labels.
# End of iteration 2, added 55 new labels.
# End of iteration 3, added 63 new labels.
# End of iteration 4, added 43 new labels.
# End of iteration 5, added 50 new labels.
# End of iteration 6, added 34 new labels.
# End of iteration 7, added 21 new labels.
# End of iteration 8, added 11 new labels.
# End of iteration 9, added 13 new labels.
# End of iteration 10, added 5 new labels.
# SelfTrainingClassifier(estimator=LogisticRegression(max_iter=500),
#                        threshold=0.8, verbose=True)

# %%
#prediksi
pred_unlabeled_enc = self_training.predict(X_unlabeled_vec)

#Decoding angka ke label
unlabeled_df[label_col] = [inv_label_map[p] for p in pred_unlabeled_enc]

# %%
final_df = pd.concat([labeled_df, unlabeled_df]).sort_index()

# %%
final_df.head(20)
# Out:
#                                               content  score  \
# 0   suka berguna banget, program dan internalnya l...      5
# 1   Terbaru sangat praktis,program dan internalnya...      5
# 2   Asliii sangat praktis,program dan internalnya ...      5
# 3   Asli sangat praktis,program dan internalnya le...      5
# 4   Asli sangat praktis,program dan internalnya le...      5
# 5   Asli sangat praktis,program dan internalnya le...      5
# 6   Bagus mayan praktis,program dan internalnya le...      5
# 7   Asli sangat praktis,program dan internalnya le...      5
# 8   Asli praktis juga harga terjangkau, programnya...      5
# 9   Asli top banget,program dan internalnya lebih ...      5
# 10  Asli Sip loh gan aplikasinya, program & intern...      5
# 11  Asli Sip ya gan,program & internalnya lebih me...      5
# 12  Asli mantep pool gan,program & internalnya leb...      5
# 13  Bagus & praktis jugaharga,terjangkau, .program...      5
# 14  Asli mantep pool gan,program & internalnya leb...      5
# 15  Asli mantap lag gan,program & internalnya lebi...      5
# 16  Sampurasun NAU-NAU beraksi!!Asli mantap lah ga...      5
# 17  Aplikasi perbankan sangat keren. program & int...      5
# 18  Terbaru sangat praktis,program dan internalnya...      5
# 19  sangat membantu praktis,programnya lebih memad...      5
#
#                                        review_cleaned    label
# 0   suka berguna banget program internalnya fleksi...   netral
# 1   terbaru praktis program internalnya memadai pa...   netral
# 2   asli praktis program internalnya memadai pakai...   netral
# 3   asli praktis program internalnya memadai pakai...   netral
# 4   asli praktis program internalnya memadai pakai...   netral
# 5   asli praktis program internalnya memadai pakai...   netral
# 6   bagus mayan praktis program internalnya memada...   netral
# 7   asli praktis program internalnya memadai pakai...   netral
# 8   asli praktis harga terjangkau programnya inter...   netral
# 9   asli banget program internalnya memadai pakai ...   netral
# 10  asli aplikasinya program internalnya memadai j...   netral
# 11  asli program internalnya memadai jalankan beba...   netral
# 12  asli mantep pool program internalnya memadai b...  positif
# 13  bagus praktis jugaharga terjangkau programnya ...  positif
# 14  asli mantep pool program internalnya memadai b...  positif
# 15  asli mantap program internalnya memadai diguna...  positif
# 16  sampurasun naunau beraksi asli mantap program ...  positif
# 17  aplikasi perbankan keren program internalnya b...   netral
# 18  terbaru praktis program internalnya memadai pa...   netral
# 19  membantu praktis programnya memadai pakai beba...   netral

# %%
final_df.to_csv("Pelabelan Self-Training.csv", index=False)
